# %% [markdown]
# <a href="https://colab.research.google.com/github/artanebibi/Datasets/blob/main/Sentiment_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install selenium

# %%
# !pip install python-dotenv

# %%
import pandas as pd
import transformers
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from sklearn.model_selection import train_test_split
import selenium as sns
from queue import Queue
import threading
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.common.exceptions import WebDriverException
from datetime import datetime

# %% [markdown]
# Freezing the un-needed parameters from fin-bert model to fasten up the training process. While focusing only on fine-tuning the already trained finBERT model

# %% [markdown]
#  <h1> STOCK NAMES AND CODES </h1>

# %%
stocks = [
    "Komercijalna banka AD Skopje", "Alkaloid AD Skopje", "DS Smith AD Skopje",
    "Fersped AD Skopje", "Granit AD Skopje", "Hoteli Metropol Ohrid",
    "Internesnel Hotels AD Skopje", "Makedonijaturist AD Skopje",
    "Makosped AD Skopje", "Makoteks AD Skopje", "Makpetrol AD Skopje",
    "Makstil AD Skopje", "Replek AD Skopje", "RZ Inter-Transsped AD Skopje",
    "RZ Uslugi AD Skopje", "Skopski Pazar AD Skopje", "Stopanska banka AD Bitola",
    "Teteks AD Tetovo", "TTK Banka AD Skopje", "Tutunski kombinat AD Prilep",
    "Vitaminka AD Prilep", "VV Tikves AD Kavadarci", "Zito Luks AD Skopje",
    "ZK Pelagonija AD Bitola", "Ading AD  Skopje", "Agromehanika AD Skopje",
    "Angropromet Tikvesanka AD Kavadarci",
    "ArcelorMittal (HRM) AD Skopje - dolgorocno suspendirano od kotacija",
    "Automakedonija AD Skopje", "BIM AD Sveti Nikole",
    "Blagoj Tufanov AD Radovis - dolgorocno suspendirano od kotacija",
    "Cementarnica USJE AD Skopje", "Centralna kooperativna banka AD Skopje",
    "Debarski Bani –Capa AD  Debar", "Dimko Mitrev AD Veles", "Evropa AD Skopje",
    "Fabrika Karpos AD Skopje", "FAKOM AD Skopje", "Fruktal Mak AD Skopje",
    "Fustelarko Borec AD Bitola", "FZC 11-ti OKTOMVRI AD Kumanovo",
    "GD-TIKVES AD Kavadarci", "Geras Cunev Konfekcija AD Strumica",
    "Geras Cunev Trgovija AD Strumica", "Grozd AD Strumica", "GTC AD Skopje",
    "Interpromet AD Tetovo", "Klanica so ladilnik AD Strumica",
    "Kristal 1923 AD Veles", "Liberti AD Skopje", "Lotarija na Makedonija AD Skopje",
    "Makedonija osiguruvane AD Skopje - Viena Insurens Grup",
    "Makedonski Telekom AD – Skopje", "Makpromet AD Stip",
    "Mermeren kombinat AD Prilep", "Moda AD Sveti Nikole", "MZT Pumpi AD Skopje",
    "Nemetali Ograzden AD Strumica", "NLB Banka AD Skopje",
    "Nova Stokovna kuka AD Strumica", "OILKO KDA Skopje", "OKTA AD Skopje",
    "Oranzerii Hamzali Strumica", "Patnicki soobrakaj Transkop AD Bitola",
    "Pekabesko AD Kadino Ilinden", "Pelisterka AD Skopje", "Popova Kula AD Demir Kapija",
    "Prilepska pivarnica AD Prilep", "Rade Koncar- Aparatna tehnika AD Skopje",
    "Rudnici Banani AD Skopje", "RZ Ekonomika AD Skopje",
    "RZ Tehnicka Kontrola AD Skopje", "Sigurnosno staklo AD Prilep",
    "Sileks AD Kratovo", "Slavej  AD Skopje", "Sovremen dom AD Prilep",
    "Stokopromet AD Skopje", "Stopanska banka AD Skopje",
    "Strumicko pole s. Vasilevo", "Tajmiste AD Kicevo - dolgorocno suspendirano od kotacija",
    "TEAL AD  Tetovo", "Tehnokomerc AD Skopje",
    "Trgotekstil Maloprodazba AD Skopje", "Triglav Osiguruvane AD Skopje",
    "Trudbenik AD Ohrid - dolgorocno suspendirano od kotacija",
    "Ugotur AD Skopje", "UNI Banka AD Skopje", "Vabtek MZT AD Skopje",
    "Veteks AD Veles", "ZAS AD Skopje", "Zito Karaorman AD Kicevo",
    "Zito Polog AD Tetovo"
]


def filter_stockname():
    stock_names = []
    for company in stocks:
        parts = company.split()
        # get rid of city names for better search
        filtered = [part for part in parts if
                    part not in {"AD", "Skopje", "Bitola", "Tetovo", "Prilep", "Kavadarci", "Ohrid", "Veles",
                                 "Kumanovo", "Sveti", "Nikole", "Debar", "Radovis", "Stip", "Ilinden", "Kicevo",
                                 "Strumica", " - dolgorocno suspendirano od kotacija"}]
        stock_names.append(" ".join(filtered))

    return stock_names


def getStockCode_db():

  stock_codes = [
    "KMB", "ALK", "KOMU", "FERS", "GRNT", "MPOL", "INHO", "MTUR", "MKSD", "MAKS",
    "MPT", "STIL", "REPL", "RZIT", "RZUS", "SPAZ", "SBT", "TETE", "TTK", "TKPR",
    "VITA", "TKVS", "ZILU", "ZPKO", "ADIN", "AMEH", "APTK", "RZLE", "AUMK", "BIM",
    "BLTU", "USJE", "CKB", "DEBA", "DIMI", "EVRO", "KPSS", "FAKM", "KONZ", "FUBT",
    "CEVI", "TIKV", "GECK", "GECT", "GRZD", "GTC", "INPR", "KLST", "BGOR", "RZLV",
    "LOTO", "KJUBI", "TEL", "MAKP", "MERM", "MODA", "MZPU", "NEME", "TNB", "NOSK",
    "OILK", "OKTA", "ORAN", "TRPS", "PKB", "LOZP", "POPK", "PPIV", "RADE", "BANA",
    "RZEK", "RZTK", "SSPR", "SIL", "SLAV", "SDOM", "STOK", "STB", "SPOL", "TAJM",
    "TEAL", "TEHN", "TSMP", "VROS", "TRDB", "RZUG", "UNI", "MZHE", "VTKS", "ZAS",
    "ZKAR", "ZPOG"
  ]


  return stock_codes

# %%
def create_driver():
    options = webdriver.ChromeOptions()
    options.add_argument("--headless")
    options.add_argument("--disable-dev-shm-usage")
    options.add_argument("--no-sandbox")
    options.add_argument("--disable-gpu")
    return webdriver.Chrome(options=options)


class SeleniumDriverPool:
    def __init__(self, max_size=5):
        self.pool = Queue(maxsize=max_size)
        self.lock = threading.Lock()
        for _ in range(max_size):
            driver = create_driver()
            self.pool.put(driver)

    def acquire_driver(self):
        with self.lock:
            return self.pool.get()

    def release_driver(self, driver):
        with self.lock:
            self.pool.put(driver)

    def close_all_drivers(self):
        while not self.pool.empty():
            driver = self.pool.get()
            driver.quit()


pool = SeleniumDriverPool(max_size=20)

# %% [markdown]
# <H1> SCRAPING <i>kapital.mk

# %%
def split_list(lst):
    mid = len(lst) // 2
    return lst[:mid], lst[mid:]

# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.common.exceptions import WebDriverException
from datetime import datetime
import threading
from queue import Queue
import os


def scrape_kapitalMK():
    stock_dataframes = {}
    filtered_stocks, filtered_stocks_2 = split_list(filter_stockname())
    stock_codes, stock_codes_2 = split_list(getStockCode_db())

    pool1 = SeleniumDriverPool(max_size=20)
    while True:
        for stock_name, stock_code in zip(filtered_stocks, stock_codes):
            data = []

            try:
                driver = pool1.acquire_driver()
                i = 1

                while True:
                    driver.get(f'https://kapital.mk/page/{i}/?s={stock_name}')
                    html_content = driver.page_source

                    if 'Error 404!' in html_content or 'Sorry, your search did not match any entries.' in html_content:
                        break

                    article_list = driver.find_elements(By.CSS_SELECTOR, ".mvp-blog-story-list li")

                    for tag in article_list:
                        a_tag = tag.find_element(By.CSS_SELECTOR, "a:nth-child(1)")
                        link = a_tag.get_attribute('href')
                        print(link)

                        try:
                            nd = pool1.acquire_driver()
                            nd.get(link)
                            date = nd.find_element(By.CSS_SELECTOR, 'time')
                            date_published = datetime.fromisoformat(date.get_attribute('datetime')).strftime("%d.%m.%Y")
                            print()
                            print(date_published)
                            print()
                            post = nd.find_element(By.CSS_SELECTOR, ".mvp-post-soc-out").text

                            actual_post = post.split('ПОВРЗАНИ ТЕМИ:')[0]
                            # print(actual_post)

                            title = a_tag.text
                            print(title)
                            data.append({'date': date_published, 'title': title, 'text': actual_post, 'link': link, 'from': 'kapital.mk'})

                        except WebDriverException as e:
                            print(f"Error occurred while processing link {link}: {e}")

                        finally:
                            pool1.release_driver(nd)

                    i += 1

            except WebDriverException as e:
                print(f"Error occurred for stock {stock_name} on page {i}: {e}")

            finally:
                pool1.release_driver(driver)

            stock_dataframes[stock_code] = pd.DataFrame(data)
        break

    pool1.close_all_drivers()

    return stock_dataframes


news2 = scrape_kapitalMK()

# %% [markdown]
# <h1>SCRAPING <i>biznisinfo.mk

# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.common.exceptions import WebDriverException
from datetime import datetime
import threading
from queue import Queue
import os



def scrape_biznisinfoMK():
    stock_dataframes = {}
    filtered_stocks_2, filtered_stocks = split_list(filter_stockname())
    stock_codes_2, stock_codes = split_list(getStockCode_db())
    pool2 = SeleniumDriverPool(max_size=20)
    while True:

        for stock_name, stock_code in zip(filtered_stocks, stock_codes):
            data = []

            try:
                driver = pool2.acquire_driver()
                i = 1

                while True:
                    driver.get(f'https://biznisinfo.mk/page/{i}/?s={stock_name}')
                    html_content = driver.page_source

                    if 'Упсссс... Error 404' in html_content or 'Нема резултати за вашето пребарување' in html_content:
                        break

                    article_list = driver.find_elements(By.CSS_SELECTOR, ".td_module_10")
                    print(f'Title: {article_list}')
                    for tag in article_list:
                        a_tag = tag.find_element(By.CSS_SELECTOR, "div:nth-child(1) > a:nth-child(1)")
                        link = a_tag.get_attribute('href')
                        print(link)

                        try:
                            nd = pool2.acquire_driver()
                            nd.get(link)

                            date = nd.find_element(By.CSS_SELECTOR, 'time')
                            date_published = datetime.strptime(date.text, "%d/%m/%Y").strftime("%d.%m.%Y")
                            print()
                            print(date_published)
                            print()

                            title = nd.find_element(By.CSS_SELECTOR, "h1.entry-title").text
                            print(title)

                            post = nd.find_element(By.CSS_SELECTOR, ".td-main-content").text
                            actual_post = post.split('Можеби ќе ве интересира и...')[0]

                            # if stock_name in actual_post:
                            data.append({'date': date_published, 'title': title, 'text': actual_post, 'link': link, 'from': 'biznisinfo.mk'})

                        except WebDriverException as e:
                            print(f"Error occurred while processing link {link}: {e}")

                        finally:
                            pool2.release_driver(nd)

                    i += 1

            except WebDriverException as e:
                print(f"Error occurred for stock {stock_name} on page {i}: {e}")

            finally:
                pool2.release_driver(driver)

            stock_dataframes[stock_code] = pd.DataFrame(data)

        break

    pool2.close_all_drivers()
    return stock_dataframes




news1 = scrape_biznisinfoMK()

# %%
for stock_name, df in news2.items():
        print(f"Data for {stock_name}:")
        print(df.to_string())

# %%
# !pip install boto3

# %%
import io
import os
import boto3
import pandas as pd
from botocore.exceptions import ClientError
from dotenv import load_dotenv

load_dotenv()


class WasabiClient:
    def __init__(self):
        access_key = 'A02ZUKINN1XDCJKJYI0D'
        secret_key = 'ZB0o901t7NOFzmkmOU34HDFg2K1Pdrr0d3XKRhjh'
        self.bucket =  'mkdstocks'
        self.s3_client = boto3.client(
            's3',
            endpoint_url='https://s3.eu-central-2.wasabisys.com',
            aws_access_key_id=access_key,
            aws_secret_access_key=secret_key,
        )

    def fetch_data(self, key: str):
        cloud_key = f"Stock_Data/{key}.csv"

        try:
            file_response = self.s3_client.get_object(Bucket=self.bucket, Key=cloud_key)
            file_content = file_response['Body'].read().decode('utf-8')  # Fix typo
            return pd.read_csv(io.StringIO(file_content))
        except ClientError as e:
            print(f"Error fetching data: {e}")
            return None

    def update_or_create(self, code: str, new_df: pd.DataFrame):
        cloud_key = f"Stock_Data/{code}.csv"

        try:
            try:
                existing_file = self.s3_client.get_object(Bucket=self.bucket, Key=cloud_key)
                existing_df = pd.read_csv(io.StringIO(existing_file['Body'].read().decode('utf-8')))
            except ClientError as e:
                if e.response['Error']['Code'] == 'NoSuchKey':
                    existing_df = None
                else:
                    print(f"Error fetching existing data: {e}")
                    return False

            combined_df = pd.concat([new_df, existing_df]).drop_duplicates() if existing_df is not None else new_df
            csv_buffer = io.StringIO()
            combined_df.to_csv(csv_buffer, index=False)
            csv_buffer.seek(0)
            self.s3_client.put_object(Bucket=self.bucket, Key=cloud_key, Body=csv_buffer.getvalue())
            print(f"Successfully appended and uploaded data for {code}.")
        except ClientError as e:
            print(f"Error uploading data: {e}")

    def create_articles(self, code: str, df: pd.DataFrame):
        cloud_key = f"Articles/{code}.csv"

        try:
            csv_buffer = io.StringIO()
            df.to_csv(csv_buffer, index=False)
            csv_buffer.seek(0)
            self.s3_client.put_object(Bucket=self.bucket, Key=cloud_key, Body=csv_buffer.getvalue())
            print(f"Successfully appended and uploaded data for {code}.")
        except ClientError as e:
            print(f"Error uploading data: {e}")

    def fetch_articles(self, code: str):
        cloud_key = f"Articles/{code}.csv"
        try:
            file_response = self.s3_client.get_object(Bucket=self.bucket, Key=cloud_key)
            file_content = file_response['Body'].read().decode('utf-8')  # Fix typo
            return pd.read_csv(io.StringIO(file_content))
        except ClientError as e:
            print(f"Error fetching data: {e}")
            return None


def get_wassabi_client():
    global wassabi_client
    if wassabi_client is None:
        raise Exception("WasabiClient is not initialized. Check BackendConfig or initialization logic.")
    return wassabi_client


# Setter for initialization
def set_wassabi_client(client):
    global wassabi_client
    wassabi_client = client


def initialize_wasabi_client():
    return WasabiClient()


wassabi_client = None

# %% [markdown]
# # *MODELS AND SENTIMENT ANALYSIS*

# %%
from transformers import MarianMTModel, MarianTokenizer, pipeline, AutoTokenizer, AutoModelForSequenceClassification

tokenizer_finbert = AutoTokenizer.from_pretrained("yiyanghkust/finbert-tone")
model_finbert = AutoModelForSequenceClassification.from_pretrained("yiyanghkust/finbert-tone",
                                                                   output_hidden_states=False)
sentiment_analyzer = pipeline("sentiment-analysis", model="yiyanghkust/finbert-tone")

# for translation
tokenizer_translator = MarianTokenizer.from_pretrained('Helsinki-NLP/opus-mt-mk-en')
model_translator = MarianMTModel.from_pretrained('Helsinki-NLP/opus-mt-mk-en')
# Out:
# Device set to use cuda:0
# tokenizer_config.json:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/1.00M [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/799k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.35M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.38k [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/models/marian/tokenization_marian.py:175: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")
# pytorch_model.bin:   0%|          | 0.00/306M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]

# %%
def split_text_into_chunks(text, max_length):
    words = text.split()
    chunks = []
    current_chunk = []

    for word in words:
        if len(' '.join(current_chunk + [word])) <= max_length:
            current_chunk.append(word)
        else:
            chunks.append(' '.join(current_chunk))
            current_chunk = [word]

    if current_chunk:
        chunks.append(' '.join(current_chunk))

    return chunks


wasabi_client = WasabiClient()

for stock_name, df in news2.items():
  final_df = []
  for index, row in df.iterrows():
    # title
    macedonian_title = row['title'].replace('„', '').replace('“', '')
    encoded_input = tokenizer_translator(macedonian_title, return_tensors='pt')
    translated = model_translator.generate(**encoded_input)
    english_title = tokenizer_translator.decode(translated[0], skip_special_tokens=True)

    final_df.append({'date': row['date'], 'title': english_title, 'link': row['link']})

    # content - cant exceed 512 tokens
    macedonian_content = row['text']
    chunks = split_text_into_chunks(macedonian_content, max_length=512)
    translated_chunks = []

    for i, chunk in enumerate(chunks):
      encoded_input2 = tokenizer_translator(chunk, return_tensors='pt')
      translated2 = model_translator.generate(**encoded_input2)
      translated_chunk = tokenizer_translator.decode(translated2[0], skip_special_tokens=True)

      result = sentiment_analyzer(translated_chunk)
      print(result[0]['label'], result[0]['score'])
      print()

      final_df.append({f'Chunk: {i}': translated_chunk, f'Sentiment: {i}': result[0]['label']})

      # Combine the translated chunks
      english_content = ' '.join(translated_chunks)

      # Print translated results
      print(f"Title (English): {english_title}")
      print(f"Content (English): {english_content}\n")



    # Optional: Save the translations to WasabiClient
  final_for_stock = pd.DataFrame(final_df)
  wasabi_client.create_articles(stock_name, final_for_stock)

# Example fetching articles
# wasabi_client.fetch_articles('Alkaloid')
# Out:
# Successfully appended and uploaded data for ZPKO.
# Neutral 0.999980092048645
#
# Title (English): INTERVIEW 7 days ago from sleep to reality The story of Dane Heems Wine Estate or, like Jovanov instead of moving his family to Slovenia, and running the entire Slovenian winery system of Puklovec Femili Weins Holding, however...
# Content (English):
#
# Positive 0.779731273651123
#
# Title (English): INTERVIEW 7 days ago from sleep to reality The story of Dane Heems Wine Estate or, like Jovanov instead of moving his family to Slovenia, and running the entire Slovenian winery system of Puklovec Femili Weins Holding, however...
# Content (English):
#
# Neutral 0.9998800754547119
#
# Title (English): INTERVIEW 7 days ago from sleep to reality The story of Dane Heems Wine Estate or, like Jovanov instead of moving his family to Slovenia, and running the entire Slovenian winery system of Puklovec Femili Weins Holding, however...
# Content (English):
#
# Neutral 0.999911904335022
#
# Title (English): INTERVIEW 7 days ago from sleep to reality The story of Dane Heems Wine Estate or, like Jovanov instead of moving his family to Slovenia, and running the entire Slovenian winery system of Puklovec Femili Weins Holding, however...
# Content (English):
#
# Positive 0.9999843835830688
#
# Title (English): INTERVIEW 7 days ago from sleep to reality The story of Dane Heems Wine Estate or, like Jovanov instead of moving his family to Slovenia, and running the entire Slovenian winery system of Puklovec Femili Weins Holding, however...
# Content (English):
#
# Neutral 0.9999793767929077
#
# Title (English): INTERVIEW 7 days ago from sleep to reality The story of Dane Heems Wine Estate or, like Jovanov instead of moving his family to Slovenia, and running the entire Slovenian winery system of Puklovec Femili Weins Holding, however...
# Content (English):
#
# Neutral 0.9999727010726929
#
# Title (English): INTERVIEW 7 days ago from sleep to reality The story of Dane Heems Wine Estate or, like Jovanov instead of moving his family to Slovenia, and running the entire Slovenian winery system of Puklovec Femili Weins Holding, however...
# Content (English):
#
# Neutral 0.7029824256896973
#
# Title (English): INTERVIEW 7 days ago from sleep to reality The story of Dane Heems Wine Estate or, like Jovanov instead of moving his family to Slovenia, and running the entire Slovenian winery system of Puklovec Femili Weins Holding, however...
# Content (English):
#
# Neutral 0.9994755387306213
#
# Title (English): INTERVIEW 7 days ago from sleep to reality The story of Dane Heems Wine Estate or, like Jovanov instead of moving his family to Slovenia, and running the entire Slovenian winery system of Puklovec Femili Weins Holding, however...
# Content (English):
#
# Neutral 0.9994210004806519
#
# Title (English): INTERVIEW 7 days ago from sleep to reality The story of Dane Heems Wine Estate or, like Jovanov instead of moving his family to Slovenia, and running the entire Slovenian winery system of Puklovec Femili Weins Holding, however...
# Content (English):
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# Streaming output truncated to the last 5000 lines.
# Positive 0.5562535524368286
#
# Title (English): THE six months ago with Amcham on the subject ...A promotion of health care by means of intellectual property Photo: Unsplash for innovative companies, the existence of strong intellectual property protection is what moves them to find, develop and offer innovative solutions to some of the...
# Content (English):
#
# Neutral 0.931868314743042
#
# Title (English): THE six months ago with Amcham on the subject ...A promotion of health care by means of intellectual property Photo: Unsplash for innovative companies, the existence of strong intellectual property protection is what moves them to find, develop and offer innovative solutions to some of the...
# Content (English):
#
# Neutral 0.995591938495636
#
# Title (English): THE six months ago with Amcham on the subject ...A promotion of health care by means of intellectual property Photo: Unsplash for innovative companies, the existence of strong intellectual property protection is what moves them to find, develop and offer innovative solutions to some of the...
# Content (English):
#
# Positive 0.9999997615814209
#
# Title (English): ECONOMIA 6 months ago Mukatev on the cover of the prestigious Romanian magazine Business: Romania is a strategic market for Alkaloid plans for Romania are aimed at increasing the team, the portfolio of products and the popularity of the manufacturer's brand, says Zivko Mukatov, General Director and President ...
# Content (English):
#
# Positive 0.9996938705444336
#
# Title (English): ECONOMIA 6 months ago Mukatev on the cover of the prestigious Romanian magazine Business: Romania is a strategic market for Alkaloid plans for Romania are aimed at increasing the team, the portfolio of products and the popularity of the manufacturer's brand, says Zivko Mukatov, General Director and President ...
# Content (English):
#
# Neutral 0.9999986886978149
#
# Title (English): ECONOMIA 6 months ago Mukatev on the cover of the prestigious Romanian magazine Business: Romania is a strategic market for Alkaloid plans for Romania are aimed at increasing the team, the portfolio of products and the popularity of the manufacturer's brand, says Zivko Mukatov, General Director and President ...
# Content (English):
#
# Positive 0.9999959468841553
#
# Title (English): ECONOMIA 6 months ago Mukatev on the cover of the prestigious Romanian magazine Business: Romania is a strategic market for Alkaloid plans for Romania are aimed at increasing the team, the portfolio of products and the popularity of the manufacturer's brand, says Zivko Mukatov, General Director and President ...
# Content (English):
#
# Positive 0.999841570854187
#
# Title (English): ECONOMIA 6 months ago Mukatev on the cover of the prestigious Romanian magazine Business: Romania is a strategic market for Alkaloid plans for Romania are aimed at increasing the team, the portfolio of products and the popularity of the manufacturer's brand, says Zivko Mukatov, General Director and President ...
# Content (English):
#
# Neutral 0.9148546457290649
#
# Title (English): ECONOMIA 6 months ago Mukatev on the cover of the prestigious Romanian magazine Business: Romania is a strategic market for Alkaloid plans for Romania are aimed at increasing the team, the portfolio of products and the popularity of the manufacturer's brand, says Zivko Mukatov, General Director and President ...
# Content (English):
#
# Neutral 0.997988224029541
#
# Title (English): ECONOMIA 6 months ago Mukatev on the cover of the prestigious Romanian magazine Business: Romania is a strategic market for Alkaloid plans for Romania are aimed at increasing the team, the portfolio of products and the popularity of the manufacturer's brand, says Zivko Mukatov, General Director and President ...
# Content (English):
#
# Positive 0.996086597442627
#
# Title (English): ECONOMIA 6 months ago Mukatev on the cover of the prestigious Romanian magazine Business: Romania is a strategic market for Alkaloid plans for Romania are aimed at increasing the team, the portfolio of products and the popularity of the manufacturer's brand, says Zivko Mukatov, General Director and President ...
# Content (English):
#
# Neutral 0.8038486242294312
#
# Title (English): ECONOMIA 6 months ago Mukatev on the cover of the prestigious Romanian magazine Business: Romania is a strategic market for Alkaloid plans for Romania are aimed at increasing the team, the portfolio of products and the popularity of the manufacturer's brand, says Zivko Mukatov, General Director and President ...
# Content (English):
#
# Positive 0.9957610964775085
#
# Title (English): ECONOMIA 6 months ago Mukatev on the cover of the prestigious Romanian magazine Business: Romania is a strategic market for Alkaloid plans for Romania are aimed at increasing the team, the portfolio of products and the popularity of the manufacturer's brand, says Zivko Mukatov, General Director and President ...
# Content (English):
#
# Positive 0.5770702958106995
#
# Title (English): ECONOMIA 6 months ago Mukatev on the cover of the prestigious Romanian magazine Business: Romania is a strategic market for Alkaloid plans for Romania are aimed at increasing the team, the portfolio of products and the popularity of the manufacturer's brand, says Zivko Mukatov, General Director and President ...
# Content (English):
#
# Neutral 0.999886155128479
#
# Title (English): ECONOMIA 6 months ago Mukatev on the cover of the prestigious Romanian magazine Business: Romania is a strategic market for Alkaloid plans for Romania are aimed at increasing the team, the portfolio of products and the popularity of the manufacturer's brand, says Zivko Mukatov, General Director and President ...
# Content (English):
#
# Neutral 0.9499525427818298
#
# Title (English): ECONOMIA 7 months ago with Amcham on the subject ... Access to intellectual property protection for small- and medium-sized enterprises Photo: Fauxels via Pexels.com even though the path of protecting intellectual property of small- and medium-sized enterprises can be vague and challenging, as high...
# Content (English):
#
# Neutral 0.9250264763832092
#
# Title (English): ECONOMIA 7 months ago with Amcham on the subject ... Access to intellectual property protection for small- and medium-sized enterprises Photo: Fauxels via Pexels.com even though the path of protecting intellectual property of small- and medium-sized enterprises can be vague and challenging, as high...
# Content (English):
#
# Neutral 0.9992194175720215
#
# Title (English): ECONOMIA 7 months ago with Amcham on the subject ... Access to intellectual property protection for small- and medium-sized enterprises Photo: Fauxels via Pexels.com even though the path of protecting intellectual property of small- and medium-sized enterprises can be vague and challenging, as high...
# Content (English):
#
# Positive 0.999998927116394
#
# Title (English): ECONOMIA 7 months ago with Amcham on the subject ... Access to intellectual property protection for small- and medium-sized enterprises Photo: Fauxels via Pexels.com even though the path of protecting intellectual property of small- and medium-sized enterprises can be vague and challenging, as high...
# Content (English):
#
# Positive 0.5165573358535767
#
# Title (English): ECONOMIA 7 months ago with Amcham on the subject ... Access to intellectual property protection for small- and medium-sized enterprises Photo: Fauxels via Pexels.com even though the path of protecting intellectual property of small- and medium-sized enterprises can be vague and challenging, as high...
# Content (English):
#
# Positive 0.9556124806404114
#
# Title (English): ECONOMIA 7 months ago with Amcham on the subject ... Access to intellectual property protection for small- and medium-sized enterprises Photo: Fauxels via Pexels.com even though the path of protecting intellectual property of small- and medium-sized enterprises can be vague and challenging, as high...
# Content (English):
#
# Neutral 0.9990585446357727
#
# Title (English): ECONOMIA 7 months ago with Amcham on the subject ... Access to intellectual property protection for small- and medium-sized enterprises Photo: Fauxels via Pexels.com even though the path of protecting intellectual property of small- and medium-sized enterprises can be vague and challenging, as high...
# Content (English):
#
# Neutral 0.5799499154090881
#
# Title (English): ECONOMIA 7 months ago with Amcham on the subject ... Access to intellectual property protection for small- and medium-sized enterprises Photo: Fauxels via Pexels.com even though the path of protecting intellectual property of small- and medium-sized enterprises can be vague and challenging, as high...
# Content (English):
#
# Neutral 0.9994163513183594
#
# Title (English): ECONOMIA 7 months ago with Amcham on the subject ... Access to intellectual property protection for small- and medium-sized enterprises Photo: Fauxels via Pexels.com even though the path of protecting intellectual property of small- and medium-sized enterprises can be vague and challenging, as high...
# Content (English):
#
# Positive 0.7982334494590759
#
# Title (English): ECONOMIA 7 months ago with Amcham on the subject ... Access to intellectual property protection for small- and medium-sized enterprises Photo: Fauxels via Pexels.com even though the path of protecting intellectual property of small- and medium-sized enterprises can be vague and challenging, as high...
# Content (English):
#
# Neutral 0.8048460483551025
#
# Title (English): ECONOMIA 7 months ago with Amcham on the subject ... Access to intellectual property protection for small- and medium-sized enterprises Photo: Fauxels via Pexels.com even though the path of protecting intellectual property of small- and medium-sized enterprises can be vague and challenging, as high...
# Content (English):
#
# Neutral 0.9981406927108765
#
# Title (English): ECONOMIA 7 months ago with Amcham on the subject ... Access to intellectual property protection for small- and medium-sized enterprises Photo: Fauxels via Pexels.com even though the path of protecting intellectual property of small- and medium-sized enterprises can be vague and challenging, as high...
# Content (English):
#
# Positive 0.9996670484542847
#
# Title (English): ECONOMIA 7 months ago with Amcham on the subject ... Access to intellectual property protection for small- and medium-sized enterprises Photo: Fauxels via Pexels.com even though the path of protecting intellectual property of small- and medium-sized enterprises can be vague and challenging, as high...
# Content (English):
#
# Neutral 0.9990459084510803
#
# Title (English): Police 7 months ago Michelle's Plan to Destroy Von der Leyen Court Games to the Most Powerful People in the EU
# Content (English):
#
# Neutral 0.9832362532615662
#
# Title (English): Police 7 months ago Michelle's Plan to Destroy Von der Leyen Court Games to the Most Powerful People in the EU
# Content (English):
#
# Neutral 0.9987953901290894
#
# Title (English): Police 7 months ago Michelle's Plan to Destroy Von der Leyen Court Games to the Most Powerful People in the EU
# Content (English):
#
# Neutral 0.9999514818191528
#
# Title (English): Police 7 months ago Michelle's Plan to Destroy Von der Leyen Court Games to the Most Powerful People in the EU
# Content (English):
#
# Positive 0.9999817609786987
#
# Title (English): Police 7 months ago Michelle's Plan to Destroy Von der Leyen Court Games to the Most Powerful People in the EU
# Content (English):
#
# Neutral 0.996329128742218
#
# Title (English): Police 7 months ago Michelle's Plan to Destroy Von der Leyen Court Games to the Most Powerful People in the EU
# Content (English):
#
# Negative 0.9355069994926453
#
# Title (English): Police 7 months ago Michelle's Plan to Destroy Von der Leyen Court Games to the Most Powerful People in the EU
# Content (English):
#
# Negative 0.9795672297477722
#
# Title (English): Police 7 months ago Michelle's Plan to Destroy Von der Leyen Court Games to the Most Powerful People in the EU
# Content (English):
#
# Neutral 0.9834098815917969
#
# Title (English): Police 7 months ago Michelle's Plan to Destroy Von der Leyen Court Games to the Most Powerful People in the EU
# Content (English):
#
# Neutral 0.999805748462677
#
# Title (English): Police 7 months ago Michelle's Plan to Destroy Von der Leyen Court Games to the Most Powerful People in the EU
# Content (English):
#
# Neutral 0.9999629259109497
#
# Title (English): Police 7 months ago Michelle's Plan to Destroy Von der Leyen Court Games to the Most Powerful People in the EU
# Content (English):
#
# Negative 0.9938132762908936
#
# Title (English): REGION has seven months ago in Croatia several ambitious robot development projects are not world robotic champions, but are trying to catch up
# Content (English):
#
# Neutral 0.9999562501907349
#
# Title (English): REGION has seven months ago in Croatia several ambitious robot development projects are not world robotic champions, but are trying to catch up
# Content (English):
#
# Neutral 0.9912804961204529
#
# Title (English): REGION has seven months ago in Croatia several ambitious robot development projects are not world robotic champions, but are trying to catch up
# Content (English):
#
# Neutral 0.9999855756759644
#
# Title (English): REGION has seven months ago in Croatia several ambitious robot development projects are not world robotic champions, but are trying to catch up
# Content (English):
#
# Positive 0.9387426376342773
#
# Title (English): REGION has seven months ago in Croatia several ambitious robot development projects are not world robotic champions, but are trying to catch up
# Content (English):
#
# Neutral 0.998755931854248
#
# Title (English): REGION has seven months ago in Croatia several ambitious robot development projects are not world robotic champions, but are trying to catch up
# Content (English):
#
# Neutral 0.9999923706054688
#
# Title (English): REGION has seven months ago in Croatia several ambitious robot development projects are not world robotic champions, but are trying to catch up
# Content (English):
#
# Positive 1.0
#
# Title (English): REGION has seven months ago in Croatia several ambitious robot development projects are not world robotic champions, but are trying to catch up
# Content (English):
#
# Positive 0.9986973404884338
#
# Title (English): REGION has seven months ago in Croatia several ambitious robot development projects are not world robotic champions, but are trying to catch up
# Content (English):
#
# Positive 0.9995761513710022
#
# Title (English): REGION has seven months ago in Croatia several ambitious robot development projects are not world robotic champions, but are trying to catch up
# Content (English):
#
# Positive 0.9800193309783936
#
# Title (English): REGION has seven months ago in Croatia several ambitious robot development projects are not world robotic champions, but are trying to catch up
# Content (English):
#
# Positive 0.9980833530426025
#
# Title (English): REGION has seven months ago in Croatia several ambitious robot development projects are not world robotic champions, but are trying to catch up
# Content (English):
#
# Neutral 0.9981552958488464
#
# Title (English): REGION has seven months ago in Croatia several ambitious robot development projects are not world robotic champions, but are trying to catch up
# Content (English):
#
# Neutral 0.9999988079071045
#
# Title (English): REGION has seven months ago in Croatia several ambitious robot development projects are not world robotic champions, but are trying to catch up
# Content (English):
#
# Neutral 0.9998326301574707
#
# Title (English): REGION has seven months ago in Croatia several ambitious robot development projects are not world robotic champions, but are trying to catch up
# Content (English):
#
# Neutral 0.999984860420227
#
# Title (English): REGION has seven months ago in Croatia several ambitious robot development projects are not world robotic champions, but are trying to catch up
# Content (English):
#
# Neutral 0.9999794960021973
#
# Title (English): REGION has seven months ago in Croatia several ambitious robot development projects are not world robotic champions, but are trying to catch up
# Content (English):
#
# Neutral 0.9999606609344482
#
# Title (English): REGION has seven months ago in Croatia several ambitious robot development projects are not world robotic champions, but are trying to catch up
# Content (English):
#
# Neutral 0.9999804496765137
#
# Title (English): REGION has seven months ago in Croatia several ambitious robot development projects are not world robotic champions, but are trying to catch up
# Content (English):
#
# Neutral 0.9999804496765137
#
# Title (English): REGION has seven months ago in Croatia several ambitious robot development projects are not world robotic champions, but are trying to catch up
# Content (English):
#
# Neutral 0.9999828338623047
#
# Title (English): REGION has seven months ago in Croatia several ambitious robot development projects are not world robotic champions, but are trying to catch up
# Content (English):
#
# Neutral 0.9996557235717773
#
# Title (English): REGION has seven months ago in Croatia several ambitious robot development projects are not world robotic champions, but are trying to catch up
# Content (English):
#
# Neutral 0.9795225858688354
#
# Title (English): REGION has seven months ago in Croatia several ambitious robot development projects are not world robotic champions, but are trying to catch up
# Content (English):
#
# Positive 0.9999969005584717
#
# Title (English): REGION has seven months ago in Croatia several ambitious robot development projects are not world robotic champions, but are trying to catch up
# Content (English):
#
# Negative 0.9763100147247314
#
# Title (English): ECONOMIA 7 months ago Balkan route of trafficking in counterfeit products with Amcham on the topic... to protect intellectual property rights
# Content (English):
#
# Neutral 0.9997679591178894
#
# Title (English): ECONOMIA 7 months ago Balkan route of trafficking in counterfeit products with Amcham on the topic... to protect intellectual property rights
# Content (English):
#
# Positive 0.9999752044677734
#
# Title (English): ECONOMIA 7 months ago Balkan route of trafficking in counterfeit products with Amcham on the topic... to protect intellectual property rights
# Content (English):
#
# Negative 0.8178244233131409
#
# Title (English): ECONOMIA 7 months ago Balkan route of trafficking in counterfeit products with Amcham on the topic... to protect intellectual property rights
# Content (English):
#
# Negative 0.9997203946113586
#
# Title (English): ECONOMIA 7 months ago Balkan route of trafficking in counterfeit products with Amcham on the topic... to protect intellectual property rights
# Content (English):
#
# Neutral 0.9994795918464661
#
# Title (English): ECONOMIA 7 months ago Balkan route of trafficking in counterfeit products with Amcham on the topic... to protect intellectual property rights
# Content (English):
#
# Neutral 0.9999831914901733
#
# Title (English): ECONOMIA 7 months ago Balkan route of trafficking in counterfeit products with Amcham on the topic... to protect intellectual property rights
# Content (English):
#
# Neutral 0.9999992847442627
#
# Title (English): ECONOMIA 7 months ago Balkan route of trafficking in counterfeit products with Amcham on the topic... to protect intellectual property rights
# Content (English):
#
# Neutral 0.9999936819076538
#
# Title (English): ECONOMIA 7 months ago Balkan route of trafficking in counterfeit products with Amcham on the topic... to protect intellectual property rights
# Content (English):
#
# Neutral 0.9995880722999573
#
# Title (English): ECONOMIA 7 months ago Balkan route of trafficking in counterfeit products with Amcham on the topic... to protect intellectual property rights
# Content (English):
#
# Neutral 0.9971715807914734
#
# Title (English): ECONOMIA 7 months ago Balkan route of trafficking in counterfeit products with Amcham on the topic... to protect intellectual property rights
# Content (English):
#
# Positive 0.9198196530342102
#
# Title (English): ECONOMIA 7 months ago Balkan route of trafficking in counterfeit products with Amcham on the topic... to protect intellectual property rights
# Content (English):
#
# Positive 0.9999692440032959
#
# Title (English): MAKEDONIA 7 months ago Mukatev of Alkaloid and Ninovski of Breinster shared experiences with the youth Conference of Halk Banka ▪ Wisdom Guardians
# Content (English):
#
# Neutral 0.9999344348907471
#
# Title (English): MAKEDONIA 7 months ago Mukatev of Alkaloid and Ninovski of Breinster shared experiences with the youth Conference of Halk Banka ▪ Wisdom Guardians
# Content (English):
#
# Positive 0.8794206380844116
#
# Title (English): MAKEDONIA 7 months ago Mukatev of Alkaloid and Ninovski of Breinster shared experiences with the youth Conference of Halk Banka ▪ Wisdom Guardians
# Content (English):
#
# Positive 0.9999998807907104
#
# Title (English): MAKEDONIA 7 months ago Mukatev of Alkaloid and Ninovski of Breinster shared experiences with the youth Conference of Halk Banka ▪ Wisdom Guardians
# Content (English):
#
# Positive 0.9965336322784424
#
# Title (English): MAKEDONIA 7 months ago Mukatev of Alkaloid and Ninovski of Breinster shared experiences with the youth Conference of Halk Banka ▪ Wisdom Guardians
# Content (English):
#
# Positive 0.9999594688415527
#
# Title (English): MAKEDONIA 7 months ago Mukatev of Alkaloid and Ninovski of Breinster shared experiences with the youth Conference of Halk Banka ▪ Wisdom Guardians
# Content (English):
#
# Positive 0.9626314043998718
#
# Title (English): MAKEDONIA 7 months ago Mukatev of Alkaloid and Ninovski of Breinster shared experiences with the youth Conference of Halk Banka ▪ Wisdom Guardians
# Content (English):
#
# Positive 0.9998862743377686
#
# Title (English): MAKEDONIA 7 months ago Mukatev of Alkaloid and Ninovski of Breinster shared experiences with the youth Conference of Halk Banka ▪ Wisdom Guardians
# Content (English):
#
# Neutral 0.6421326398849487
#
# Title (English): MAKEDONIA 7 months ago Mukatev of Alkaloid and Ninovski of Breinster shared experiences with the youth Conference of Halk Banka ▪ Wisdom Guardians
# Content (English):
#
# Neutral 0.9991814494132996
#
# Title (English): MAKEDONIA 7 months ago Mukatev of Alkaloid and Ninovski of Breinster shared experiences with the youth Conference of Halk Banka ▪ Wisdom Guardians
# Content (English):
#
# Positive 0.651110053062439
#
# Title (English): MAKEDONIA 7 months ago Mukatev of Alkaloid and Ninovski of Breinster shared experiences with the youth Conference of Halk Banka ▪ Wisdom Guardians
# Content (English):
#
# Neutral 0.8776092529296875
#
# Title (English): MAKEDONIA 7 months ago Mukatev of Alkaloid and Ninovski of Breinster shared experiences with the youth Conference of Halk Banka ▪ Wisdom Guardians
# Content (English):
#
# Positive 0.9999992847442627
#
# Title (English): ECONOMIA 7 months ago Analysis MASIT: Almost 1.5 billion euros in revenues made ICT companies last year grow in the IT-Communication sector of 15% annually
# Content (English):
#
# Neutral 0.9972244501113892
#
# Title (English): ECONOMIA 7 months ago Analysis MASIT: Almost 1.5 billion euros in revenues made ICT companies last year grow in the IT-Communication sector of 15% annually
# Content (English):
#
# Positive 1.0
#
# Title (English): ECONOMIA 7 months ago Analysis MASIT: Almost 1.5 billion euros in revenues made ICT companies last year grow in the IT-Communication sector of 15% annually
# Content (English):
#
# Positive 1.0
#
# Title (English): ECONOMIA 7 months ago Analysis MASIT: Almost 1.5 billion euros in revenues made ICT companies last year grow in the IT-Communication sector of 15% annually
# Content (English):
#
# Neutral 0.8453302979469299
#
# Title (English): ECONOMIA 7 months ago Analysis MASIT: Almost 1.5 billion euros in revenues made ICT companies last year grow in the IT-Communication sector of 15% annually
# Content (English):
#
# Positive 0.9939688444137573
#
# Title (English): ECONOMIA 7 months ago Analysis MASIT: Almost 1.5 billion euros in revenues made ICT companies last year grow in the IT-Communication sector of 15% annually
# Content (English):
#
# Neutral 0.9969268441200256
#
# Title (English): ECONOMIA 7 months ago Analysis MASIT: Almost 1.5 billion euros in revenues made ICT companies last year grow in the IT-Communication sector of 15% annually
# Content (English):
#
# Positive 0.9982023239135742
#
# Title (English): ECONOMIA 7 months ago Analysis MASIT: Almost 1.5 billion euros in revenues made ICT companies last year grow in the IT-Communication sector of 15% annually
# Content (English):
#
# Positive 0.9999185800552368
#
# Title (English): ECONOMIA 7 months ago Analysis MASIT: Almost 1.5 billion euros in revenues made ICT companies last year grow in the IT-Communication sector of 15% annually
# Content (English):
#
# Neutral 0.9844968318939209
#
# Title (English): ECONOMIA 7 months ago Analysis MASIT: Almost 1.5 billion euros in revenues made ICT companies last year grow in the IT-Communication sector of 15% annually
# Content (English):
#
# Neutral 0.9999476671218872
#
# Title (English): ECONOMIA 7 months ago Analysis MASIT: Almost 1.5 billion euros in revenues made ICT companies last year grow in the IT-Communication sector of 15% annually
# Content (English):
#
# Positive 0.9988163709640503
#
# Title (English): BANKI 7 months ago non-cash payments increased by 30%, a significant increase in toxicised payment transactions in the region
# Content (English):
#
# Positive 0.8244368433952332
#
# Title (English): BANKI 7 months ago non-cash payments increased by 30%, a significant increase in toxicised payment transactions in the region
# Content (English):
#
# Positive 0.9999997615814209
#
# Title (English): BANKI 7 months ago non-cash payments increased by 30%, a significant increase in toxicised payment transactions in the region
# Content (English):
#
# Positive 0.9254885911941528
#
# Title (English): BANKI 7 months ago non-cash payments increased by 30%, a significant increase in toxicised payment transactions in the region
# Content (English):
#
# Positive 0.9999996423721313
#
# Title (English): BANKI 7 months ago non-cash payments increased by 30%, a significant increase in toxicised payment transactions in the region
# Content (English):
#
# Positive 1.0
#
# Title (English): BANKI 7 months ago non-cash payments increased by 30%, a significant increase in toxicised payment transactions in the region
# Content (English):
#
# Positive 0.9999926090240479
#
# Title (English): BANKI 7 months ago non-cash payments increased by 30%, a significant increase in toxicised payment transactions in the region
# Content (English):
#
# Positive 0.9999691247940063
#
# Title (English): BANKI 7 months ago non-cash payments increased by 30%, a significant increase in toxicised payment transactions in the region
# Content (English):
#
# Negative 0.9998230338096619
#
# Title (English): ECONOMIA 7 Months Ago Special Contribution: New Technologies in Transport and Logistic Special Attachment Transport and Logistic Future on Wheels · Global Voices
# Content (English):
#
# Neutral 0.977959394454956
#
# Title (English): ECONOMIA 7 Months Ago Special Contribution: New Technologies in Transport and Logistic Special Attachment Transport and Logistic Future on Wheels · Global Voices
# Content (English):
#
# Neutral 0.9996364116668701
#
# Title (English): ECONOMIA 7 Months Ago Special Contribution: New Technologies in Transport and Logistic Special Attachment Transport and Logistic Future on Wheels · Global Voices
# Content (English):
#
# Negative 0.9999947547912598
#
# Title (English): ECONOMIA 7 Months Ago Special Contribution: New Technologies in Transport and Logistic Special Attachment Transport and Logistic Future on Wheels · Global Voices
# Content (English):
#
# Neutral 0.6577830910682678
#
# Title (English): ECONOMIA 7 Months Ago Special Contribution: New Technologies in Transport and Logistic Special Attachment Transport and Logistic Future on Wheels · Global Voices
# Content (English):
#
# Negative 0.9916473627090454
#
# Title (English): ECONOMIA 7 Months Ago Special Contribution: New Technologies in Transport and Logistic Special Attachment Transport and Logistic Future on Wheels · Global Voices
# Content (English):
#
# Negative 0.9996640682220459
#
# Title (English): ECONOMIA 7 Months Ago Special Contribution: New Technologies in Transport and Logistic Special Attachment Transport and Logistic Future on Wheels · Global Voices
# Content (English):
#
# Negative 0.8620304465293884
#
# Title (English): ECONOMIA 7 Months Ago Special Contribution: New Technologies in Transport and Logistic Special Attachment Transport and Logistic Future on Wheels · Global Voices
# Content (English):
#
# Negative 0.9999067783355713
#
# Title (English): ECONOMIA 7 Months Ago Special Contribution: New Technologies in Transport and Logistic Special Attachment Transport and Logistic Future on Wheels · Global Voices
# Content (English):
#
# Neutral 0.7772777080535889
#
# Title (English): ECONOMIA 7 Months Ago Special Contribution: New Technologies in Transport and Logistic Special Attachment Transport and Logistic Future on Wheels · Global Voices
# Content (English):
#
# Negative 0.9999861717224121
#
# Title (English): ECONOMIA 7 Months Ago Special Contribution: New Technologies in Transport and Logistic Special Attachment Transport and Logistic Future on Wheels · Global Voices
# Content (English):
#
# Neutral 0.9974198341369629
#
# Title (English): ECONOMIA 7 Months Ago Special Contribution: New Technologies in Transport and Logistic Special Attachment Transport and Logistic Future on Wheels · Global Voices
# Content (English):
#
# Neutral 0.958267331123352
#
# Title (English): ECONOMIA 7 Months Ago Special Contribution: New Technologies in Transport and Logistic Special Attachment Transport and Logistic Future on Wheels · Global Voices
# Content (English):
#
# Positive 0.9999175071716309
#
# Title (English): ECONOMIA 7 Months Ago Special Contribution: New Technologies in Transport and Logistic Special Attachment Transport and Logistic Future on Wheels · Global Voices
# Content (English):
#
# Positive 0.9995261430740356
#
# Title (English): ECONOMIA 7 Months Ago Special Contribution: New Technologies in Transport and Logistic Special Attachment Transport and Logistic Future on Wheels · Global Voices
# Content (English):
#
# Neutral 0.9999113082885742
#
# Title (English): ECONOMIA 7 Months Ago Special Contribution: New Technologies in Transport and Logistic Special Attachment Transport and Logistic Future on Wheels · Global Voices
# Content (English):
#
# Neutral 0.9997681975364685
#
# Title (English): ECONOMIA 7 Months Ago Special Contribution: New Technologies in Transport and Logistic Special Attachment Transport and Logistic Future on Wheels · Global Voices
# Content (English):
#
# Neutral 0.55056232213974
#
# Title (English): ECONOMIA 7 Months Ago Special Contribution: New Technologies in Transport and Logistic Special Attachment Transport and Logistic Future on Wheels · Global Voices
# Content (English):
#
# Neutral 0.99940025806427
#
# Title (English): ECONOMIA 7 Months Ago Special Contribution: New Technologies in Transport and Logistic Special Attachment Transport and Logistic Future on Wheels · Global Voices
# Content (English):
#
# Neutral 0.9912853837013245
#
# Title (English): ECONOMIA 7 Months Ago Special Contribution: New Technologies in Transport and Logistic Special Attachment Transport and Logistic Future on Wheels · Global Voices
# Content (English):
#
# Neutral 0.973301351070404
#
# Title (English): ECONOMIA 7 Months Ago Special Contribution: New Technologies in Transport and Logistic Special Attachment Transport and Logistic Future on Wheels · Global Voices
# Content (English):
#
# Positive 0.9999861717224121
#
# Title (English): ECONOMIA 7 Months Ago Special Contribution: New Technologies in Transport and Logistic Special Attachment Transport and Logistic Future on Wheels · Global Voices
# Content (English):
#
# Positive 0.9940250515937805
#
# Title (English): ECONOMIA 7 Months Ago Special Contribution: New Technologies in Transport and Logistic Special Attachment Transport and Logistic Future on Wheels · Global Voices
# Content (English):
#
# Positive 0.9989307522773743
#
# Title (English): ECONOMIA 7 Months Ago Special Contribution: New Technologies in Transport and Logistic Special Attachment Transport and Logistic Future on Wheels · Global Voices
# Content (English):
#
# Neutral 0.9803168773651123
#
# Title (English): ECONOMIA 7 Months Ago Special Contribution: New Technologies in Transport and Logistic Special Attachment Transport and Logistic Future on Wheels · Global Voices
# Content (English):
#
# Positive 0.9999979734420776
#
# Title (English): ECONOMIA 7 Months Ago Special Contribution: New Technologies in Transport and Logistic Special Attachment Transport and Logistic Future on Wheels · Global Voices
# Content (English):
#
# Positive 0.9999786615371704
#
# Title (English): ECONOMIA 7 Months Ago Special Contribution: New Technologies in Transport and Logistic Special Attachment Transport and Logistic Future on Wheels · Global Voices
# Content (English):
#
# Negative 0.9993521571159363
#
# Title (English): ECONOMIA 7 Months Ago Special Contribution: New Technologies in Transport and Logistic Special Attachment Transport and Logistic Future on Wheels · Global Voices
# Content (English):
#
# Negative 0.9978978633880615
#
# Title (English): ECONOMIA 7 Months Ago Special Contribution: New Technologies in Transport and Logistic Special Attachment Transport and Logistic Future on Wheels · Global Voices
# Content (English):
#
# Neutral 0.8662330508232117
#
# Title (English): BANKI for 7 months ago Pat non-banking companies have already been allowed to provide payment services in Macedonia, and cross-border competition increases in financial business
# Content (English):
#
# Positive 0.9999998807907104
#
# Title (English): BANKI for 7 months ago Pat non-banking companies have already been allowed to provide payment services in Macedonia, and cross-border competition increases in financial business
# Content (English):
#
# Neutral 0.9999699592590332
#
# Title (English): BANKI for 7 months ago Pat non-banking companies have already been allowed to provide payment services in Macedonia, and cross-border competition increases in financial business
# Content (English):
#
# Neutral 0.9985199570655823
#
# Title (English): BANKI for 7 months ago Pat non-banking companies have already been allowed to provide payment services in Macedonia, and cross-border competition increases in financial business
# Content (English):
#
# Neutral 0.49040889739990234
#
# Title (English): BANKI for 7 months ago Pat non-banking companies have already been allowed to provide payment services in Macedonia, and cross-border competition increases in financial business
# Content (English):
#
# Neutral 0.845146894454956
#
# Title (English): BANKI for 7 months ago Pat non-banking companies have already been allowed to provide payment services in Macedonia, and cross-border competition increases in financial business
# Content (English):
#
# Positive 0.999984622001648
#
# Title (English): BANKI for 7 months ago Pat non-banking companies have already been allowed to provide payment services in Macedonia, and cross-border competition increases in financial business
# Content (English):
#
# Positive 0.6352740526199341
#
# Title (English): BANKI for 7 months ago Pat non-banking companies have already been allowed to provide payment services in Macedonia, and cross-border competition increases in financial business
# Content (English):
#
# Positive 0.9773371815681458
#
# Title (English): BANKI for 7 months ago Pat non-banking companies have already been allowed to provide payment services in Macedonia, and cross-border competition increases in financial business
# Content (English):
#
# Neutral 0.9992377758026123
#
# Title (English): BANKI for 7 months ago Pat non-banking companies have already been allowed to provide payment services in Macedonia, and cross-border competition increases in financial business
# Content (English):
#
# Positive 0.9944777488708496
#
# Title (English): BANKI for 7 months ago Pat non-banking companies have already been allowed to provide payment services in Macedonia, and cross-border competition increases in financial business
# Content (English):
#
# Neutral 0.9997404217720032
#
# Title (English): BANKI for 7 months ago Pat non-banking companies have already been allowed to provide payment services in Macedonia, and cross-border competition increases in financial business
# Content (English):
#
# Positive 0.9981877207756042
#
# Title (English): BANKI for 7 months ago Pat non-banking companies have already been allowed to provide payment services in Macedonia, and cross-border competition increases in financial business
# Content (English):
#
# Neutral 0.987658679485321
#
# Title (English): BANKI for 7 months ago Pat non-banking companies have already been allowed to provide payment services in Macedonia, and cross-border competition increases in financial business
# Content (English):
#
# Positive 1.0
#
# Title (English): BANKI for 7 months ago Pat non-banking companies have already been allowed to provide payment services in Macedonia, and cross-border competition increases in financial business
# Content (English):
#
# Positive 0.7677844762802124
#
# Title (English): BANKI for 7 months ago Pat non-banking companies have already been allowed to provide payment services in Macedonia, and cross-border competition increases in financial business
# Content (English):
#
# Neutral 0.9999562501907349
#
# Title (English): BANKI for 7 months ago Pat non-banking companies have already been allowed to provide payment services in Macedonia, and cross-border competition increases in financial business
# Content (English):
#
# Negative 0.998331606388092
#
# Title (English): CONENTARE 7 months ago with Amcham on the subject ... The Balkan route of trade in counterfeit products Photo: Tima Miroshnikenko, via Pexels though all countries in the region have a similar, and on paper a strong, legal framework, problems still arise when it comes to...
# Content (English):
#
# Neutral 0.9997106194496155
#
# Title (English): CONENTARE 7 months ago with Amcham on the subject ... The Balkan route of trade in counterfeit products Photo: Tima Miroshnikenko, via Pexels though all countries in the region have a similar, and on paper a strong, legal framework, problems still arise when it comes to...
# Content (English):
#
# Positive 0.999976396560669
#
# Title (English): CONENTARE 7 months ago with Amcham on the subject ... The Balkan route of trade in counterfeit products Photo: Tima Miroshnikenko, via Pexels though all countries in the region have a similar, and on paper a strong, legal framework, problems still arise when it comes to...
# Content (English):
#
# Positive 0.9998433589935303
#
# Title (English): CONENTARE 7 months ago with Amcham on the subject ... The Balkan route of trade in counterfeit products Photo: Tima Miroshnikenko, via Pexels though all countries in the region have a similar, and on paper a strong, legal framework, problems still arise when it comes to...
# Content (English):
#
# Negative 0.9861667156219482
#
# Title (English): CONENTARE 7 months ago with Amcham on the subject ... The Balkan route of trade in counterfeit products Photo: Tima Miroshnikenko, via Pexels though all countries in the region have a similar, and on paper a strong, legal framework, problems still arise when it comes to...
# Content (English):
#
# Neutral 0.6637635827064514
#
# Title (English): CONENTARE 7 months ago with Amcham on the subject ... The Balkan route of trade in counterfeit products Photo: Tima Miroshnikenko, via Pexels though all countries in the region have a similar, and on paper a strong, legal framework, problems still arise when it comes to...
# Content (English):
#
# Neutral 0.999969482421875
#
# Title (English): CONENTARE 7 months ago with Amcham on the subject ... The Balkan route of trade in counterfeit products Photo: Tima Miroshnikenko, via Pexels though all countries in the region have a similar, and on paper a strong, legal framework, problems still arise when it comes to...
# Content (English):
#
# Neutral 0.9999988079071045
#
# Title (English): CONENTARE 7 months ago with Amcham on the subject ... The Balkan route of trade in counterfeit products Photo: Tima Miroshnikenko, via Pexels though all countries in the region have a similar, and on paper a strong, legal framework, problems still arise when it comes to...
# Content (English):
#
# Neutral 0.9999935626983643
#
# Title (English): CONENTARE 7 months ago with Amcham on the subject ... The Balkan route of trade in counterfeit products Photo: Tima Miroshnikenko, via Pexels though all countries in the region have a similar, and on paper a strong, legal framework, problems still arise when it comes to...
# Content (English):
#
# Neutral 0.9999864101409912
#
# Title (English): CONENTARE 7 months ago with Amcham on the subject ... The Balkan route of trade in counterfeit products Photo: Tima Miroshnikenko, via Pexels though all countries in the region have a similar, and on paper a strong, legal framework, problems still arise when it comes to...
# Content (English):
#
# Neutral 0.9572190046310425
#
# Title (English): CONENTARE 7 months ago with Amcham on the subject ... The Balkan route of trade in counterfeit products Photo: Tima Miroshnikenko, via Pexels though all countries in the region have a similar, and on paper a strong, legal framework, problems still arise when it comes to...
# Content (English):
#
# Positive 0.9994227886199951
#
# Title (English): CONENTARE 7 months ago with Amcham on the subject ... The Balkan route of trade in counterfeit products Photo: Tima Miroshnikenko, via Pexels though all countries in the region have a similar, and on paper a strong, legal framework, problems still arise when it comes to...
# Content (English):
#
# Neutral 0.9986794590950012
#
# Title (English): MONAGED / MARCETING 7 months ago how to have meetings: it doesn't have to be long, annoying and boring, it might be different from the meetings and colleagues being one of the frequent reasons for discontent with the work in companies. It's a shame if they are, because they have to be a great opportunity...
# Content (English):
#
# Neutral 0.843776285648346
#
# Title (English): MONAGED / MARCETING 7 months ago how to have meetings: it doesn't have to be long, annoying and boring, it might be different from the meetings and colleagues being one of the frequent reasons for discontent with the work in companies. It's a shame if they are, because they have to be a great opportunity...
# Content (English):
#
# Negative 0.992195725440979
#
# Title (English): MONAGED / MARCETING 7 months ago how to have meetings: it doesn't have to be long, annoying and boring, it might be different from the meetings and colleagues being one of the frequent reasons for discontent with the work in companies. It's a shame if they are, because they have to be a great opportunity...
# Content (English):
#
# Neutral 0.9999985694885254
#
# Title (English): MONAGED / MARCETING 7 months ago how to have meetings: it doesn't have to be long, annoying and boring, it might be different from the meetings and colleagues being one of the frequent reasons for discontent with the work in companies. It's a shame if they are, because they have to be a great opportunity...
# Content (English):
#
# Neutral 0.9999986886978149
#
# Title (English): MONAGED / MARCETING 7 months ago how to have meetings: it doesn't have to be long, annoying and boring, it might be different from the meetings and colleagues being one of the frequent reasons for discontent with the work in companies. It's a shame if they are, because they have to be a great opportunity...
# Content (English):
#
# Neutral 0.9935373663902283
#
# Title (English): MONAGED / MARCETING 7 months ago how to have meetings: it doesn't have to be long, annoying and boring, it might be different from the meetings and colleagues being one of the frequent reasons for discontent with the work in companies. It's a shame if they are, because they have to be a great opportunity...
# Content (English):
#
# Neutral 0.7257333993911743
#
# Title (English): MONAGED / MARCETING 7 months ago how to have meetings: it doesn't have to be long, annoying and boring, it might be different from the meetings and colleagues being one of the frequent reasons for discontent with the work in companies. It's a shame if they are, because they have to be a great opportunity...
# Content (English):
#
# Neutral 0.9999454021453857
#
# Title (English): MONAGED / MARCETING 7 months ago how to have meetings: it doesn't have to be long, annoying and boring, it might be different from the meetings and colleagues being one of the frequent reasons for discontent with the work in companies. It's a shame if they are, because they have to be a great opportunity...
# Content (English):
#
# Neutral 0.9756370186805725
#
# Title (English): MONAGED / MARCETING 7 months ago how to have meetings: it doesn't have to be long, annoying and boring, it might be different from the meetings and colleagues being one of the frequent reasons for discontent with the work in companies. It's a shame if they are, because they have to be a great opportunity...
# Content (English):
#
# Neutral 0.8016599416732788
#
# ...
#
# Neutral 0.8933290243148804
#
# Title (English): ECONOMIA 10 months ago new European carbon duties can cause social unrest EU climate policies on the back of farmers and vulnerable categories
# Content (English):
#
# Positive 0.999953031539917
#
# Title (English): MAKEDONIA 10 months ago a special contribution to Women in Business: Women are not equal in any country in the world
# Content (English):
#
# Positive 0.718886137008667
#
# Title (English): MAKEDONIA 10 months ago a special contribution to Women in Business: Women are not equal in any country in the world
# Content (English):
#
# Neutral 0.9998729228973389
#
# Title (English): MAKEDONIA 10 months ago a special contribution to Women in Business: Women are not equal in any country in the world
# Content (English):
#
# Neutral 0.9995300769805908
#
# Title (English): MAKEDONIA 10 months ago a special contribution to Women in Business: Women are not equal in any country in the world
# Content (English):
#
# Positive 0.9998488426208496
#
# Title (English): MAKEDONIA 10 months ago a special contribution to Women in Business: Women are not equal in any country in the world
# Content (English):
#
# Neutral 0.9385412931442261
#
# Title (English): MAKEDONIA 10 months ago a special contribution to Women in Business: Women are not equal in any country in the world
# Content (English):
#
# Neutral 0.9966913461685181
#
# Title (English): MAKEDONIA 10 months ago a special contribution to Women in Business: Women are not equal in any country in the world
# Content (English):
#
# Neutral 0.9996823072433472
#
# Title (English): MAKEDONIA 10 months ago a special contribution to Women in Business: Women are not equal in any country in the world
# Content (English):
#
# Positive 0.6523337960243225
#
# Title (English): MAKEDONIA 10 months ago a special contribution to Women in Business: Women are not equal in any country in the world
# Content (English):
#
# Positive 0.9879943132400513
#
# Title (English): MAKEDONIA 10 months ago a special contribution to Women in Business: Women are not equal in any country in the world
# Content (English):
#
# Positive 0.9999991655349731
#
# Title (English): MAKEDONIA 10 months ago a special contribution to Women in Business: Women are not equal in any country in the world
# Content (English):
#
# Negative 0.8493006825447083
#
# Title (English): MAKEDONIA 10 months ago a special contribution to Women in Business: Women are not equal in any country in the world
# Content (English):
#
# Neutral 0.8885393738746643
#
# Title (English): MAKEDONIA 10 months ago a special contribution to Women in Business: Women are not equal in any country in the world
# Content (English):
#
# Positive 0.998910665512085
#
# Title (English): MAKEDONIA 10 months ago a special contribution to Women in Business: Women are not equal in any country in the world
# Content (English):
#
# Neutral 0.9969512224197388
#
# Title (English): MAKEDONIA 10 months ago a special contribution to Women in Business: Women are not equal in any country in the world
# Content (English):
#
# Positive 0.9034804105758667
#
# Title (English): MAKEDONIA 10 months ago a special contribution to Women in Business: Women are not equal in any country in the world
# Content (English):
#
# Neutral 0.8757544755935669
#
# Title (English): MAKEDONIA 10 months ago a special contribution to Women in Business: Women are not equal in any country in the world
# Content (English):
#
# Positive 0.9999891519546509
#
# Title (English): MAKEDONIA 10 months ago a special contribution to Women in Business: Women are not equal in any country in the world
# Content (English):
#
# Neutral 0.9998273849487305
#
# Title (English): MAKEDONIA 10 months ago a special contribution to Women in Business: Women are not equal in any country in the world
# Content (English):
#
# Neutral 0.9312679171562195
#
# Title (English): MAKEDONIA 10 months ago a special contribution to Women in Business: Women are not equal in any country in the world
# Content (English):
#
# Neutral 0.9977158308029175
#
# Title (English): MAKEDONIA 10 months ago a special contribution to Women in Business: Women are not equal in any country in the world
# Content (English):
#
# Negative 0.9999953508377075
#
# Title (English): ECONOMIA 10 months ago the prices of raw materials stabilised in February, market expects further slowdown in US stock growth
# Content (English):
#
# Neutral 0.6704393625259399
#
# Title (English): ECONOMIA 10 months ago the prices of raw materials stabilised in February, market expects further slowdown in US stock growth
# Content (English):
#
# Negative 0.9878259301185608
#
# Title (English): ECONOMIA 10 months ago the prices of raw materials stabilised in February, market expects further slowdown in US stock growth
# Content (English):
#
# Neutral 0.9876854419708252
#
# Title (English): ECONOMIA 10 months ago the prices of raw materials stabilised in February, market expects further slowdown in US stock growth
# Content (English):
#
# Negative 0.997925877571106
#
# Title (English): ECONOMIA 10 months ago the prices of raw materials stabilised in February, market expects further slowdown in US stock growth
# Content (English):
#
# Negative 0.6776663661003113
#
# Title (English): ECONOMIA 10 months ago the prices of raw materials stabilised in February, market expects further slowdown in US stock growth
# Content (English):
#
# Neutral 0.9419843554496765
#
# Title (English): ECONOMIA 10 months ago the prices of raw materials stabilised in February, market expects further slowdown in US stock growth
# Content (English):
#
# Neutral 0.997157096862793
#
# Title (English): ECONOMIA 10 months ago the prices of raw materials stabilised in February, market expects further slowdown in US stock growth
# Content (English):
#
# Negative 0.9999909400939941
#
# Title (English): ECONOMIA 10 months ago the prices of raw materials stabilised in February, market expects further slowdown in US stock growth
# Content (English):
#
# Positive 0.9794492721557617
#
# Title (English): ECONOMIA 10 months ago the prices of raw materials stabilised in February, market expects further slowdown in US stock growth
# Content (English):
#
# Negative 0.999993085861206
#
# Title (English): ECONOMIA 10 months ago the prices of raw materials stabilised in February, market expects further slowdown in US stock growth
# Content (English):
#
# Positive 0.9938182234764099
#
# Title (English): ECONOMIA 10 months ago the prices of raw materials stabilised in February, market expects further slowdown in US stock growth
# Content (English):
#
# Negative 0.9998606443405151
#
# Title (English): ECONOMIA 10 months ago the prices of raw materials stabilised in February, market expects further slowdown in US stock growth
# Content (English):
#
# Positive 0.9944663643836975
#
# Title (English): ECONOMIA 10 months ago the prices of raw materials stabilised in February, market expects further slowdown in US stock growth
# Content (English):
#
# Negative 0.8008371591567993
#
# Title (English): ECONOMIA 10 months ago the prices of raw materials stabilised in February, market expects further slowdown in US stock growth
# Content (English):
#
# Negative 0.5932460427284241
#
# Title (English): ECONOMIA 10 months ago the prices of raw materials stabilised in February, market expects further slowdown in US stock growth
# Content (English):
#
# Positive 0.999995231628418
#
# Title (English): ECONOMIA 10 months ago the prices of raw materials stabilised in February, market expects further slowdown in US stock growth
# Content (English):
#
# Negative 0.9937113523483276
#
# Title (English): ECONOMIA 10 months ago the prices of raw materials stabilised in February, market expects further slowdown in US stock growth
# Content (English):
#
# Positive 0.6531839966773987
#
# Title (English): ECONOMIA 10 months ago the prices of raw materials stabilised in February, market expects further slowdown in US stock growth
# Content (English):
#
# Neutral 0.8698979020118713
#
# Title (English): ECONOMIA 10 months ago the prices of raw materials stabilised in February, market expects further slowdown in US stock growth
# Content (English):
#
# Positive 0.9999972581863403
#
# Title (English): ECONOMIA 10 months ago the prices of raw materials stabilised in February, market expects further slowdown in US stock growth
# Content (English):
#
# Negative 0.9999971389770508
#
# Title (English): ECONOMIA 10 months ago the prices of raw materials stabilised in February, market expects further slowdown in US stock growth
# Content (English):
#
# Positive 0.9659488797187805
#
# Title (English): ECONOMIA 10 months ago the prices of raw materials stabilised in February, market expects further slowdown in US stock growth
# Content (English):
#
# Positive 0.999997615814209
#
# Title (English): ECONOMIA 10 months ago the prices of raw materials stabilised in February, market expects further slowdown in US stock growth
# Content (English):
#
# Positive 0.9999991655349731
#
# Title (English): WORLD 10 months ago a prominent American investor sold technology stocks and invested in gold Ballans between traditional and modern
# Content (English):
#
# Neutral 0.9999734163284302
#
# Title (English): WORLD 10 months ago a prominent American investor sold technology stocks and invested in gold Ballans between traditional and modern
# Content (English):
#
# Positive 0.9999926090240479
#
# Title (English): WORLD 10 months ago a prominent American investor sold technology stocks and invested in gold Ballans between traditional and modern
# Content (English):
#
# Positive 0.9853475093841553
#
# Title (English): WORLD 10 months ago a prominent American investor sold technology stocks and invested in gold Ballans between traditional and modern
# Content (English):
#
# Positive 0.9642893671989441
#
# Title (English): WORLD 10 months ago a prominent American investor sold technology stocks and invested in gold Ballans between traditional and modern
# Content (English):
#
# Positive 0.9988651275634766
#
# Title (English): WORLD 10 months ago a prominent American investor sold technology stocks and invested in gold Ballans between traditional and modern
# Content (English):
#
# Neutral 0.999552309513092
#
# Title (English): WORLD 10 months ago a prominent American investor sold technology stocks and invested in gold Ballans between traditional and modern
# Content (English):
#
# Neutral 0.9961925745010376
#
# Title (English): WORLD 10 months ago a prominent American investor sold technology stocks and invested in gold Ballans between traditional and modern
# Content (English):
#
# Positive 0.7455669641494751
#
# Title (English): WORLD 10 months ago a prominent American investor sold technology stocks and invested in gold Ballans between traditional and modern
# Content (English):
#
# Neutral 0.9895553588867188
#
# Title (English): WORLD 10 months ago a prominent American investor sold technology stocks and invested in gold Ballans between traditional and modern
# Content (English):
#
# Neutral 0.999942421913147
#
# Title (English): WORLD 10 months ago a prominent American investor sold technology stocks and invested in gold Ballans between traditional and modern
# Content (English):
#
# Neutral 0.9680168032646179
#
# Title (English): WORLD 10 months ago a prominent American investor sold technology stocks and invested in gold Ballans between traditional and modern
# Content (English):
#
# Negative 0.9760377407073975
#
# Title (English): TECHNOLOGIES / Companies 10 months after Meta and Google, the EU punishes them for the first time and Apple and TikTook Technology and Regulation
# Content (English):
#
# Neutral 0.9133535623550415
#
# Title (English): TECHNOLOGIES / Companies 10 months after Meta and Google, the EU punishes them for the first time and Apple and TikTook Technology and Regulation
# Content (English):
#
# Negative 0.9435046911239624
#
# Title (English): TECHNOLOGIES / Companies 10 months after Meta and Google, the EU punishes them for the first time and Apple and TikTook Technology and Regulation
# Content (English):
#
# Negative 0.9985439777374268
#
# Title (English): TECHNOLOGIES / Companies 10 months after Meta and Google, the EU punishes them for the first time and Apple and TikTook Technology and Regulation
# Content (English):
#
# Negative 0.9999394416809082
#
# Title (English): TECHNOLOGIES / Companies 10 months after Meta and Google, the EU punishes them for the first time and Apple and TikTook Technology and Regulation
# Content (English):
#
# Neutral 0.7470423579216003
#
# Title (English): TECHNOLOGIES / Companies 10 months after Meta and Google, the EU punishes them for the first time and Apple and TikTook Technology and Regulation
# Content (English):
#
# Neutral 0.9977321624755859
#
# Title (English): TECHNOLOGIES / Companies 10 months after Meta and Google, the EU punishes them for the first time and Apple and TikTook Technology and Regulation
# Content (English):
#
# Neutral 0.9567381143569946
#
# Title (English): TECHNOLOGIES / Companies 10 months after Meta and Google, the EU punishes them for the first time and Apple and TikTook Technology and Regulation
# Content (English):
#
# Neutral 0.9646760821342468
#
# Title (English): TECHNOLOGIES / Companies 10 months after Meta and Google, the EU punishes them for the first time and Apple and TikTook Technology and Regulation
# Content (English):
#
# Positive 1.0
#
# Title (English): ECONOMIA 10 months ago another record year for the insurance sector: What's next? Liberalisation of mandatory car insurance Special Insurance another record year for the insurance sector
# Content (English):
#
# Positive 1.0
#
# Title (English): ECONOMIA 10 months ago another record year for the insurance sector: What's next? Liberalisation of mandatory car insurance Special Insurance another record year for the insurance sector
# Content (English):
#
# Positive 0.9999858140945435
#
# Title (English): ECONOMIA 10 months ago another record year for the insurance sector: What's next? Liberalisation of mandatory car insurance Special Insurance another record year for the insurance sector
# Content (English):
#
# Positive 0.8849722146987915
#
# Title (English): ECONOMIA 10 months ago another record year for the insurance sector: What's next? Liberalisation of mandatory car insurance Special Insurance another record year for the insurance sector
# Content (English):
#
# Positive 0.9996501207351685
#
# Title (English): ECONOMIA 10 months ago another record year for the insurance sector: What's next? Liberalisation of mandatory car insurance Special Insurance another record year for the insurance sector
# Content (English):
#
# Positive 0.9998894929885864
#
# Title (English): ECONOMIA 10 months ago another record year for the insurance sector: What's next? Liberalisation of mandatory car insurance Special Insurance another record year for the insurance sector
# Content (English):
#
# Positive 0.9994863271713257
#
# Title (English): ECONOMIA 10 months ago another record year for the insurance sector: What's next? Liberalisation of mandatory car insurance Special Insurance another record year for the insurance sector
# Content (English):
#
# Positive 0.9566624760627747
#
# Title (English): ECONOMIA 10 months ago another record year for the insurance sector: What's next? Liberalisation of mandatory car insurance Special Insurance another record year for the insurance sector
# Content (English):
#
# Positive 0.9999998807907104
#
# Title (English): ECONOMIA 10 months ago another record year for the insurance sector: What's next? Liberalisation of mandatory car insurance Special Insurance another record year for the insurance sector
# Content (English):
#
# Neutral 0.9947212934494019
#
# Title (English): ECONOMIA 10 months ago another record year for the insurance sector: What's next? Liberalisation of mandatory car insurance Special Insurance another record year for the insurance sector
# Content (English):
#
# Positive 1.0
#
# Title (English): ECONOMIA 10 months ago another record year for the insurance sector: What's next? Liberalisation of mandatory car insurance Special Insurance another record year for the insurance sector
# Content (English):
#
# Negative 0.7684516310691833
#
# Title (English): ECONOMIA 10 months ago another record year for the insurance sector: What's next? Liberalisation of mandatory car insurance Special Insurance another record year for the insurance sector
# Content (English):
